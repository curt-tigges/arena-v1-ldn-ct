# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/repos/arena-v1-ldn-ct/w1d3/
# Out:
# /content/drive/MyDrive/repos/arena-v1-ldn-ct/w1d3

# %%
# !pip install -Uqq fancy_einsum einops gradio

# %%
import torch as t

# %%
# !ls
# Out:
# 100-0.txt	   nlp_modules.py	     transformer_modules.py
# cnn_modules.py	   __pycache__		     w1d3_sol_1_sampling.ipynb
# flagged		   sample_methods.py	     w1d3_sol_2_shakespeare.ipynb
# gradio_demo.ipynb  solutions_sampling.py     w1d3_transformer_shakespeare.pt
# id_word_map.pkl    solutions_shakespeare.py  word_id_map.pkl

# %%
import sys 
sys.path.append('../common_modules')

# %%
from sample_methods import sample_tokens
from nlp_modules import WordsTokenizer

# %%
def generate(input):

    MODEL_FILENAME = "./w1d3_transformer_shakespeare.pt"

    model = t.load(MODEL_FILENAME, map_location=t.device('cpu'))
    model.eval()

    tokenizer = WordsTokenizer(16)
    tokenizer.load_saved()

    text_output = sample_tokens(model, tokenizer, input, max_tokens_generated=100, temperature=1.0, top_k=10)
    return text_output

# %%
import gradio as gr

def greet(name):
    return "Hello " + name + "!"

demo = gr.Interface(fn=generate, inputs="text", outputs="text")

demo.launch(debug=True)
# Out:
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
#
# Using Embedded Colab Mode (NEW). If you have issues, please use share=True and file an issue at https://github.com/gradio-app/gradio/
# Note: opening the browser inspector may crash Embedded Colab Mode.
#
# To create a public link, set `share=True` in `launch()`.
# Keyboard interruption in main thread... closing server.
# (<gradio.routes.App at 0x7fdcec739750>, 'http://127.0.0.1:7861/', None)
